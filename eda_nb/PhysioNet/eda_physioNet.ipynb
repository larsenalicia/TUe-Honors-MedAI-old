# %%
# Import 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Import data 02
f_df = pd.read_csv("../../dataset/multitaper-spectra-recorded-during-gabaergic-anesthetic-unconsciousness-1.0.0/Volunteer/02_f.csv")
l_df = pd.read_csv("../../dataset/multitaper-spectra-recorded-during-gabaergic-anesthetic-unconsciousness-1.0.0/Volunteer/02_l.csv")
sdb_df = pd.read_csv("../../dataset/multitaper-spectra-recorded-during-gabaergic-anesthetic-unconsciousness-1.0.0/Volunteer/02_Sdb.csv", header=None).to_numpy()
t_df = pd.read_csv("../../dataset/multitaper-spectra-recorded-during-gabaergic-anesthetic-unconsciousness-1.0.0/Volunteer/02_t.csv")

# %% [markdown]
# Note: The sdb_df is the output from doing multitaper spectral analysis, in which they estimate the power of each frequency bands of 0.5Hz and between 0 and 50. So 100 rows here.

# %% [markdown]
# #### 1. General EDAs

# %%
plt.plot(sdb_df[0, :])

# %%
len(sdb_df[1, :])
# Out:
# 5190

# %%
# Plot 
fig, axes = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(15, 10))
axes[0].plot(l_df)
axes[1].scatter(y=sdb_df[1, :], x=range(1, len(sdb_df[1, :]) + 1), s=0.1)

plt.xlabel('Time')
plt.tight_layout()
plt.show()
